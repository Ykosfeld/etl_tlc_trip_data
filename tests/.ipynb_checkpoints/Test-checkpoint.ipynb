# %%
import os, sys
os.environ["PYSPARK_PYTHON"] = sys.executable

# %%
from pyspark.sql import SparkSession

spark = SparkSession.builder.appName("Spark for Test").master("local[*]").getOrCreate()
spark
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/12/17 16:00:42 WARN Utils: Your hostname, yoshimatsu, resolves to a loopback address: 127.0.1.1; using 192.168.86.120 instead (on interface enp0s31f6)
# 25/12/17 16:00:42 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/12/17 16:00:42 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
#             <div>
#                 <p><b>SparkSession - in-memory</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://192.168.86.120:4040">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v4.0.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>local[*]</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>Spark for Test</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
yellow_cab = spark.read.option("header", "true").parquet("../data/yellow_tripdata_2025-10.parquet")

# %%
yellow_cab.count()
# Out:
# 4428699

# %%
yellow_cab_sample = yellow_cab.sample(0.0001).toPandas()

# %%
yellow_cab_sample.head()
# Out:
#    VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0         2  2025-10-01 07:24:33   2025-10-01 08:10:14              1.0
# 1         1  2025-10-01 09:25:34   2025-10-01 09:41:44              1.0
# 2         2  2025-10-01 10:50:40   2025-10-01 11:11:19              1.0
# 3         2  2025-10-01 10:35:13   2025-10-01 11:01:58              3.0
# 4         1  2025-10-01 11:10:26   2025-10-01 12:12:22              1.0
#
#    trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0          15.84         1.0                  N           138           231
# 1           2.30         1.0                  N           249           246
# 2           1.16         1.0                  N           246            48
# 3           3.42         1.0                  N           246           261
# 4          14.20        99.0                  N           101           188
#
#    payment_type  fare_amount  extra  mta_tax  tip_amount  tolls_amount  \
# 0             1         68.1   5.00      0.5       16.96          6.94
# 1             1         17.0   3.25      0.5        0.00          0.00
# 2             1         17.7   0.00      0.5        4.49          0.00
# 3             1         26.1   0.00      0.5        6.17          0.00
# 4             1         47.5   0.00      0.5        0.00          0.00
#
#    improvement_surcharge  total_amount  congestion_surcharge  Airport_fee  \
# 0                    1.0        103.50                   2.5         1.75
# 1                    1.0         21.75                   2.5         0.00
# 2                    1.0         26.94                   2.5         0.00
# 3                    1.0         37.02                   2.5         0.00
# 4                    0.0         48.00                   0.0         0.00
#
#    cbd_congestion_fee
# 0                0.75
# 1                0.75
# 2                0.75
# 3                0.75
# 4                0.00

# %%
green_cab = spark.read.option("header", "true").parquet("../data/green_tripdata_2025-10.parquet")

# %%
green_cab.count() * 0.01
# Out:
# 494.16

# %%
green_cab_sample = green_cab.sample(0.01).toPandas()

# %%
green_cab_sample.columns
# Out:
# Index(['VendorID', 'lpep_pickup_datetime', 'lpep_dropoff_datetime',
#        'store_and_fwd_flag', 'RatecodeID', 'PULocationID', 'DOLocationID',
#        'passenger_count', 'trip_distance', 'fare_amount', 'extra', 'mta_tax',
#        'tip_amount', 'tolls_amount', 'ehail_fee', 'improvement_surcharge',
#        'total_amount', 'payment_type', 'trip_type', 'congestion_surcharge',
#        'cbd_congestion_fee'],
#       dtype='object')

# %%
yellow_cab_sample.columns
# Out:
# Index(['VendorID', 'tpep_pickup_datetime', 'tpep_dropoff_datetime',
#        'passenger_count', 'trip_distance', 'RatecodeID', 'store_and_fwd_flag',
#        'PULocationID', 'DOLocationID', 'payment_type', 'fare_amount', 'extra',
#        'mta_tax', 'tip_amount', 'tolls_amount', 'improvement_surcharge',
#        'total_amount', 'congestion_surcharge', 'Airport_fee',
#        'cbd_congestion_fee'],
#       dtype='object')

# %%
fhvhv = spark.read.option("header", "true").parquet("../data/fhvhv_tripdata_2025-10.parquet")

# %%
fhvhv.count() * 0.00002
# Out:
# 426.17402000000004

# %%
fhvhv_sample = fhvhv.sample(0.00002).toPandas()

# %%
fhvhv_sample.head()
# Out:
#   hvfhs_license_num dispatching_base_num originating_base_num  \
# 0            HV0003               B03404               B03404
# 1            HV0005               B03406                 None
# 2            HV0003               B03404               B03404
# 3            HV0003               B03404               B03404
# 4            HV0003               B03404               B03404
#
#      request_datetime   on_scene_datetime     pickup_datetime  \
# 0 2025-10-01 01:27:44 2025-10-01 01:29:00 2025-10-01 01:29:22
# 1 2025-10-01 04:05:44 2025-10-01 04:07:09 2025-10-01 04:08:09
# 2 2025-10-01 05:35:21 2025-10-01 05:37:14 2025-10-01 05:39:14
# 3 2025-10-01 06:22:03 2025-10-01 06:26:11 2025-10-01 06:26:11
# 4 2025-10-01 12:30:13 2025-10-01 12:31:38 2025-10-01 12:31:38
#
#      dropoff_datetime  PULocationID  DOLocationID  trip_miles  ...  \
# 0 2025-10-01 01:48:02           148           198       6.010  ...
# 1 2025-10-01 04:17:57            36           256       1.543  ...
# 2 2025-10-01 05:57:12           173           130       5.950  ...
# 3 2025-10-01 06:44:34            88            68       4.800  ...
# 4 2025-10-01 12:50:29           164           231       2.600  ...
#
#    congestion_surcharge  airport_fee  tips  driver_pay  shared_request_flag  \
# 0                  2.75          0.0  7.36       19.76                    N
# 1                  0.00          0.0  0.00        8.39                    N
# 2                  0.00          0.0  0.00       19.19                    N
# 3                  2.75          0.0  5.55       20.07                    N
# 4                  2.75          0.0  0.00       18.42                    N
#
#    shared_match_flag  access_a_ride_flag  wav_request_flag  wav_match_flag  \
# 0                  N                   N                 N               N
# 1                  N                   N                 N               N
# 2                  N                   N                 N               N
# 3                  N                   N                 N               N
# 4                  N                   N                 N               N
#
#   cbd_congestion_fee
# 0                1.5
# 1                0.0
# 2                0.0
# 3                1.5
# 4                1.5
#
# [5 rows x 25 columns]

# %%
fhvhv_sample.columns
# Out:
# Index(['hvfhs_license_num', 'dispatching_base_num', 'originating_base_num',
#        'request_datetime', 'on_scene_datetime', 'pickup_datetime',
#        'dropoff_datetime', 'PULocationID', 'DOLocationID', 'trip_miles',
#        'trip_time', 'base_passenger_fare', 'tolls', 'bcf', 'sales_tax',
#        'congestion_surcharge', 'airport_fee', 'tips', 'driver_pay',
#        'shared_request_flag', 'shared_match_flag', 'access_a_ride_flag',
#        'wav_request_flag', 'wav_match_flag', 'cbd_congestion_fee'],
#       dtype='object')

# %%
green_cab_sample.columns.symmetric_difference(yellow_cab_sample.columns)
# Out:
# Index(['Airport_fee', 'ehail_fee', 'lpep_dropoff_datetime',
#        'lpep_pickup_datetime', 'tpep_dropoff_datetime', 'tpep_pickup_datetime',
#        'trip_type'],
#       dtype='object')

# %%
yellow_cab.first()
# Out:
# Row(VendorID=1, tpep_pickup_datetime=datetime.datetime(2025, 10, 1, 0, 15, 32), tpep_dropoff_datetime=datetime.datetime(2025, 10, 1, 1, 4, 3), passenger_count=1, trip_distance=17.2, RatecodeID=2, store_and_fwd_flag='N', PULocationID=132, DOLocationID=107, payment_type=1, fare_amount=70.0, extra=5.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=6.94, improvement_surcharge=1.0, total_amount=83.44, congestion_surcharge=2.5, Airport_fee=1.75, cbd_congestion_fee=0.75)

# %%
green_cab.first()
# Out:
# Row(VendorID=2, lpep_pickup_datetime=datetime.datetime(2025, 10, 1, 0, 21, 47), lpep_dropoff_datetime=datetime.datetime(2025, 10, 1, 0, 24, 37), store_and_fwd_flag='N', RatecodeID=1, PULocationID=247, DOLocationID=69, passenger_count=1, trip_distance=0.7, fare_amount=5.8, extra=1.0, mta_tax=0.5, tip_amount=1.7, tolls_amount=0.0, ehail_fee=None, improvement_surcharge=1.0, total_amount=10.0, payment_type=1, trip_type=1, congestion_surcharge=0.0, cbd_congestion_fee=0.0)

# %%
cabs = yellow_cab.unionByName(green_cab, allowMissingColumns=True)

# %%
cabs.sample(0.0001).toPandas()
# Out:
#      VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0           2  2025-10-01 09:23:50   2025-10-01 09:46:34              1.0
# 1           2  2025-10-01 10:32:38   2025-10-01 10:50:00              1.0
# 2           2  2025-10-01 12:30:51   2025-10-01 12:58:29              1.0
# 3           2  2025-10-01 14:27:22   2025-10-01 14:47:59              1.0
# 4           1  2025-10-01 18:16:09   2025-10-01 18:27:11              1.0
# ..        ...                  ...                   ...              ...
# 416         2                  NaT                   NaT              1.0
# 417         2                  NaT                   NaT              5.0
# 418         2                  NaT                   NaT              1.0
# 419         2                  NaT                   NaT              1.0
# 420         1                  NaT                   NaT              1.0
#
#      trip_distance  RatecodeID store_and_fwd_flag  PULocationID  DOLocationID  \
# 0             1.98         1.0                  N           161           262
# 1             2.30         1.0                  N           239           262
# 2             2.52         1.0                  N           140            43
# 3             2.48         1.0                  N           246           114
# 4             1.50         1.0                  N           236           239
# ..             ...         ...                ...           ...           ...
# 416           5.47         1.0                  N            74           138
# 417          14.27         1.0                  N            33           243
# 418           0.91         1.0                  N            74           166
# 419           2.46         1.0                  N            74           263
# 420           1.60         1.0                  N           166           116
#
#      payment_type  ...  tolls_amount  improvement_surcharge  total_amount  \
# 0               1  ...          0.00                    1.0         29.46
# 1               1  ...          0.00                    1.0         25.20
# 2               1  ...          0.00                    1.0         33.60
# 3               2  ...          0.00                    1.0         23.85
# 4               1  ...          0.00                    1.0         21.50
# ..            ...  ...           ...                    ...           ...
# 416             1  ...          6.94                    1.0         47.45
# 417             1  ...          0.00                    1.0         72.06
# 418             2  ...          0.00                    1.0         13.30
# 419             1  ...          0.00                    1.0         21.85
# 420             1  ...          0.00                    1.0         14.03
#
#      congestion_surcharge  Airport_fee  cbd_congestion_fee  \
# 0                    2.50          0.0                0.75
# 1                    2.50          0.0                0.00
# 2                    2.50          0.0                0.00
# 3                    2.50          0.0                0.75
# 4                    2.50          0.0                0.00
# ..                    ...          ...                 ...
# 416                  0.00          NaN                0.00
# 417                  2.75          NaN                0.00
# 418                  0.00          NaN                0.00
# 419                  2.75          NaN                0.00
# 420                  0.00          NaN                0.00
#
#      lpep_pickup_datetime  lpep_dropoff_datetime  ehail_fee  trip_type
# 0                     NaT                    NaT        NaN        NaN
# 1                     NaT                    NaT        NaN        NaN
# 2                     NaT                    NaT        NaN        NaN
# 3                     NaT                    NaT        NaN        NaN
# 4                     NaT                    NaT        NaN        NaN
# ..                    ...                    ...        ...        ...
# 416   2025-10-06 07:34:30    2025-10-06 07:54:19        NaN        1.0
# 417   2025-10-07 21:29:04    2025-10-07 21:54:53        NaN        1.0
# 418   2025-10-15 16:46:05    2025-10-15 16:55:02        NaN        1.0
# 419   2025-10-23 10:05:03    2025-10-23 10:19:29        NaN        1.0
# 420   2025-10-30 14:21:45    2025-10-30 14:33:46        NaN        1.0
#
# [421 rows x 24 columns]

# %%
from pyspark.sql.functions import *

# %%
cabs = cabs.withColumn("pickup_datetime", coalesce("tpep_pickup_datetime", "lpep_pickup_datetime")).drop("tpep_pickup_datetime", "lpep_pickup_datetime")
cabs = cabs.withColumn("dropoff_datetime", coalesce("tpep_dropoff_datetime", "lpep_dropoff_datetime")).drop("tpep_dropoff_datetime", "lpep_dropoff_datetime")

# %%
cabs.sample(0.0001).toPandas()
# Out:
#      VendorID  passenger_count  trip_distance  RatecodeID store_and_fwd_flag  \
# 0           2              1.0           2.26         1.0                  N
# 1           2              1.0           0.75         1.0                  N
# 2           2              1.0           1.16         1.0                  N
# 3           2              1.0           0.63         1.0                  N
# 4           2              1.0           0.59         1.0                  N
# ..        ...              ...            ...         ...                ...
# 420         2              1.0          10.95         5.0                  N
# 421         2              1.0           0.10         1.0                  N
# 422         2              5.0           0.91         1.0                  N
# 423         2              1.0           4.54         1.0                  N
# 424         2              1.0           3.41         1.0                  N
#
#      PULocationID  DOLocationID  payment_type  fare_amount  extra  ...  \
# 0             142           164             1         12.8    1.0  ...
# 1             236           236             1          8.6    0.0  ...
# 2             164           234             1          9.3    0.0  ...
# 3             100           161             1          7.9    2.5  ...
# 4             113           234             1          5.8    2.5  ...
# ..            ...           ...           ...          ...    ...  ...
# 420            33           138             1         49.0    5.0  ...
# 421            18            18             2          3.7    1.0  ...
# 422            43           238             1          7.2    0.0  ...
# 423           244           244             1         25.4    2.5  ...
# 424           166           262             1         22.6    2.5  ...
#
#      tolls_amount  improvement_surcharge  total_amount  congestion_surcharge  \
# 0             0.0                    1.0         24.12                  2.50
# 1             0.0                    1.0         15.12                  2.50
# 2             0.0                    1.0         17.56                  2.50
# 3             0.0                    1.0         18.94                  2.50
# 4             0.0                    1.0         14.05                  2.50
# ..            ...                    ...           ...                   ...
# 420           0.0                    1.0         68.75                  0.00
# 421           0.0                    1.0          6.20                  0.00
# 422           0.0                    1.0         13.74                  2.75
# 423           0.0                    1.0         35.28                  0.00
# 424           0.0                    1.0         35.22                  2.75
#
#      Airport_fee  cbd_congestion_fee  ehail_fee  trip_type  \
# 0            0.0                0.75        NaN        NaN
# 1            0.0                0.00        NaN        NaN
# 2            0.0                0.75        NaN        NaN
# 3            0.0                0.75        NaN        NaN
# 4            0.0                0.75        NaN        NaN
# ..           ...                 ...        ...        ...
# 420          NaN                0.00        NaN        2.0
# 421          NaN                0.00        NaN        1.0
# 422          NaN                0.00        NaN        1.0
# 423          NaN                0.00        NaN        1.0
# 424          NaN                0.00        NaN        1.0
#
#         pickup_datetime    dropoff_datetime
# 0   2025-10-01 00:25:03 2025-10-01 00:35:30
# 1   2025-10-01 09:56:03 2025-10-01 10:03:26
# 2   2025-10-01 10:10:29 2025-10-01 10:18:16
# 3   2025-10-01 16:52:11 2025-10-01 16:59:43
# 4   2025-10-01 16:06:28 2025-10-01 16:09:55
# ..                  ...                 ...
# 420 2025-10-12 15:48:38 2025-10-12 16:10:48
# 421 2025-10-16 22:23:02 2025-10-16 22:24:05
# 422 2025-10-23 08:40:35 2025-10-23 08:45:09
# 423 2025-10-30 17:19:43 2025-10-30 17:41:35
# 424 2025-10-31 17:13:12 2025-10-31 17:35:46
#
# [425 rows x 22 columns]

# %%
cabs.filter(col("total_amount").isNull()).count()
# Out:
# 0

# %%
# Out:
# VendorID: 0
# passenger_count: 995902
# trip_distance: 0
# RatecodeID: 995902
# store_and_fwd_flag: 995902
# PULocationID: 0
# DOLocationID: 0
# payment_type: 5015
# fare_amount: 0
# extra: 0
# mta_tax: 0
# tip_amount: 0
# tolls_amount: 0
# improvement_surcharge: 0
# total_amount: 0
# congestion_surcharge: 995902
# Airport_fee: 1040303
# cbd_congestion_fee: 0
# ehail_fee: 4478115
# trip_type: 4433716
# pickup_datetime: 0
# dropoff_datetime: 0

# %%
cabs.first()
# Out:
# Row(VendorID=1, passenger_count=1, trip_distance=17.2, RatecodeID=2, store_and_fwd_flag='N', PULocationID=132, DOLocationID=107, payment_type=1, fare_amount=70.0, extra=5.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=6.94, improvement_surcharge=1.0, total_amount=83.44, congestion_surcharge=2.5, Airport_fee=1.75, cbd_congestion_fee=0.75, ehail_fee=None, trip_type=None, pickup_datetime=datetime.datetime(2025, 10, 1, 0, 15, 32), dropoff_datetime=datetime.datetime(2025, 10, 1, 1, 4, 3))

# %%
cabs = cabs.withColumn(
    "payment_type", 
    when(col("payment_type") == 5, None).otherwise(col("payment_type")))

# %%
cabs.filter(col("payment_type")==5).count()
# Out:
# 0

# %%
cabs = cabs.withColumn(
    "RatecodeID",
    when(col("RatecodeID") == 99, None).otherwise(col("RatecodeID")))

# %%
cabs.filter(col("RatecodeID").isNull()).count()
# Out:
# 1099363

# %%
cabs = cabs.withColumn(
        "Airport_fee",
        when(col("Airport_fee").isNull(), 0.0)
        .otherwise(col("Airport_fee"))
    )

# %%
cabs.filter(col("Airport_fee")==0).count()
# Out:
# 4166333

# %%
cabs = cabs.withColumn(
        "congestion_surcharge",
        when(col("congestion_surcharge").isNull(), 0.0)
        .otherwise(col("congestion_surcharge"))
    )

# %%
cabs.filter(col("congestion_surcharge")==0).count()
# Out:
# 1367354

# %%
for c in cabs.columns:
    n_nulls = cabs.filter(col(c).isNull()).count()
    print(f"{c}: {n_nulls}")
# Out:
# VendorID: 0
# passenger_count: 995902
# trip_distance: 0
# RatecodeID: 1099363
# store_and_fwd_flag: 995902
# PULocationID: 0
# DOLocationID: 0
# payment_type: 5016
# fare_amount: 0
# extra: 0
# mta_tax: 0
# tip_amount: 0
# tolls_amount: 0
# improvement_surcharge: 0
# total_amount: 0
# congestion_surcharge: 0
# Airport_fee: 0
# cbd_congestion_fee: 0
# ehail_fee: 4478115
# trip_type: 4433716
# pickup_datetime: 0
# dropoff_datetime: 0

# %%
cabs_deduped = cabs.dropDuplicates()
duplicate_count = cabs.count() - cabs_deduped.count()

# %%
duplicate_count
# Out:
# 0

# %%
cabs = cabs.withColumn(
    "weekday_num",
    dayofweek(col("pickup_datetime"))
)

# %%
cabs.first()
# Out:
# Row(VendorID=1, passenger_count=1, trip_distance=17.2, RatecodeID=2, store_and_fwd_flag='N', PULocationID=132, DOLocationID=107, payment_type=1, fare_amount=70.0, extra=5.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=6.94, improvement_surcharge=1.0, total_amount=83.44, congestion_surcharge=2.5, Airport_fee=1.75, cbd_congestion_fee=0.75, ehail_fee=None, trip_type=None, pickup_datetime=datetime.datetime(2025, 10, 1, 0, 15, 32), dropoff_datetime=datetime.datetime(2025, 10, 1, 1, 4, 3), weekday_num=4)

# %%
cabs = cabs.withColumn(
    "trip_duration",
    expr("timestampdiff(SECOND, pickup_datetime, dropoff_datetime)")
)

# %%
cabs.first()
# Out:
# Row(VendorID=1, passenger_count=1, trip_distance=17.2, RatecodeID=2, store_and_fwd_flag='N', PULocationID=132, DOLocationID=107, payment_type=1, fare_amount=70.0, extra=5.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=6.94, improvement_surcharge=1.0, total_amount=83.44, congestion_surcharge=2.5, Airport_fee=1.75, cbd_congestion_fee=0.75, ehail_fee=None, trip_type=None, pickup_datetime=datetime.datetime(2025, 10, 1, 0, 15, 32), dropoff_datetime=datetime.datetime(2025, 10, 1, 1, 4, 3), weekday_num=4, trip_duration=2911)

# %%
cabs = cabs.withColumn(
    "total_taxes",
    col("total_amount") - col("fare_amount")
)

# %%
cabs.first()
# Out:
# Row(VendorID=1, passenger_count=1, trip_distance=17.2, RatecodeID=2, store_and_fwd_flag='N', PULocationID=132, DOLocationID=107, payment_type=1, fare_amount=70.0, extra=5.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=6.94, improvement_surcharge=1.0, total_amount=83.44, congestion_surcharge=2.5, Airport_fee=1.75, cbd_congestion_fee=0.75, ehail_fee=None, trip_type=None, pickup_datetime=datetime.datetime(2025, 10, 1, 0, 15, 32), dropoff_datetime=datetime.datetime(2025, 10, 1, 1, 4, 3), weekday_num=4, trip_duration=2911, total_taxes=13.439999999999998)

# %%
h = hour(col("pickup_datetime"))

cabs = cabs.withColumn(
    "hour_bucket",
    when(h.between(0, 6), 0)
        .when(h.between(7, 12), 1)
        .when(h.between(13, 18), 2)
        .when(h.between(19, 23), 3)
)

# %%
cabs.first()
# Out:
# 25/12/17 18:33:59 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# Row(VendorID=1, passenger_count=1, trip_distance=17.2, RatecodeID=2, store_and_fwd_flag='N', PULocationID=132, DOLocationID=107, payment_type=1, fare_amount=70.0, extra=5.0, mta_tax=0.5, tip_amount=0.0, tolls_amount=6.94, improvement_surcharge=1.0, total_amount=83.44, congestion_surcharge=2.5, Airport_fee=1.75, cbd_congestion_fee=0.75, ehail_fee=None, trip_type=None, pickup_datetime=datetime.datetime(2025, 10, 1, 0, 15, 32), dropoff_datetime=datetime.datetime(2025, 10, 1, 1, 4, 3), weekday_num=4, trip_duration=2911, total_taxes=13.439999999999998, hour_bucket=0)
